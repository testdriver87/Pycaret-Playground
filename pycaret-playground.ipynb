# %%
# %pip install pycaret-ts-alpha

import time
import numpy as np
import pandas as pd

from pycaret.datasets import get_data
from pycaret.internal.pycaret_experiment import TimeSeriesExperiment
# Out:
# Requirement already satisfied: pycaret-ts-alpha in /opt/conda/lib/python3.9/site-packages (3.0.0.dev1638407153)
# Requirement already satisfied: yellowbrick>=1.0.1 in /opt/conda/lib/python3.9/site-packages (from pycaret-ts-alpha) (1.3.post1)
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.9/site-packages (from pycaret-ts-alpha) (0.11.2)
# Requirement already satisfied: tbats>=1.1.0 in /opt/conda/lib/python3.9/site-packages (from pycaret-ts-alpha) (1.1.0)
# Requirement already satisfied: mlxtend>=0.17.0 in /opt/conda/lib/python3.9/site-packages (from pycaret-ts-alpha) (0.19.0)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.9/site-packages (from pycaret-ts-alpha) (1.3.5)
# Requirement already satisfied: wordcloud in /opt/conda/lib/python3.9/site-packages (from pycaret-ts-alpha) (1.8.1)
# Requirement already satisfied: scipy<=1.5.4 in /opt/conda/lib/python3.9/site-packages (from pycaret-ts-alpha) (1.5.4)
# Requirement already satisfied: pandas-profiling>=2.8.0 in /opt/conda/lib/python3.9/site-packages (from pycaret-ts-alpha) (3.1.0)
# Requirement already satisfied: ipywidgets in /opt/conda/lib/python3.9/site-packages (from pycaret-ts-alpha) (7.6.5)
# Requirement already satisfied: lightgbm>=2.3.1 in /opt/conda/lib/python3.9/site-packages (from pycaret-ts-alpha) (3.3.2)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.9/site-packages (from pycaret-ts-alpha) (1.0.1)
# Requirement already satisfied: umap-learn in /opt/conda/lib/python3.9/site-packages (from pycaret-ts-alpha) (0.5.2)
# Requirement already satisfied: mlflow in /opt/conda/lib/python3.9/site-packages (from pycaret-ts-alpha) (1.22.0)
# Requirement already satisfied: sktime>=0.8.0 in /opt/conda/lib/python3.9/site-packages (from pycaret-ts-alpha) (0.8.1)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.9/site-packages (from pycaret-ts-alpha) (3.5.1)
# Requirement already satisfied: pyyaml<6.0.0 in /opt/conda/lib/python3.9/site-packages (from pycaret-ts-alpha) (5.4.1)
# Requirement already satisfied: kmodes>=0.10.1 in /opt/conda/lib/python3.9/site-packages (from pycaret-ts-alpha) (0.11.1)
# Requirement already satisfied: pyLDAvis in /opt/conda/lib/python3.9/site-packages (from pycaret-ts-alpha) (3.2.2)
# Requirement already satisfied: pyod in /opt/conda/lib/python3.9/site-packages (from pycaret-ts-alpha) (0.9.7)
# Requirement already satisfied: nltk in /opt/conda/lib/python3.9/site-packages (from pycaret-ts-alpha) (3.6.7)
# Requirement already satisfied: imbalanced-learn==0.7.0 in /opt/conda/lib/python3.9/site-packages (from pycaret-ts-alpha) (0.7.0)
# Requirement already satisfied: textblob in /opt/conda/lib/python3.9/site-packages (from pycaret-ts-alpha) (0.17.1)
# Requirement already satisfied: scikit-plot in /opt/conda/lib/python3.9/site-packages (from pycaret-ts-alpha) (0.3.7)
# Requirement already satisfied: numpy==1.19.5 in /opt/conda/lib/python3.9/site-packages (from pycaret-ts-alpha) (1.19.5)
# Requirement already satisfied: gensim<4.0.0 in /opt/conda/lib/python3.9/site-packages (from pycaret-ts-alpha) (3.8.3)
# Requirement already satisfied: statsmodels~=0.12.1 in /opt/conda/lib/python3.9/site-packages (from pycaret-ts-alpha) (0.12.1)
# Requirement already satisfied: Boruta in /opt/conda/lib/python3.9/site-packages (from pycaret-ts-alpha) (0.3)
# Requirement already satisfied: cufflinks>=0.17.0 in /opt/conda/lib/python3.9/site-packages (from pycaret-ts-alpha) (0.17.3)
# Requirement already satisfied: scikit-learn~=0.24.2 in /opt/conda/lib/python3.9/site-packages (from pycaret-ts-alpha) (0.24.2)
# Requirement already satisfied: IPython in /opt/conda/lib/python3.9/site-packages (from pycaret-ts-alpha) (7.31.0)
# Requirement already satisfied: plotly>=5.0.0 in /opt/conda/lib/python3.9/site-packages (from pycaret-ts-alpha) (5.5.0)
# Requirement already satisfied: spacy<2.4.0 in /opt/conda/lib/python3.9/site-packages (from pycaret-ts-alpha) (2.3.7)
# Requirement already satisfied: numba in /opt/conda/lib/python3.9/site-packages (from pycaret-ts-alpha) (0.54.1)
# Requirement already satisfied: pmdarima>=1.8.0 in /opt/conda/lib/python3.9/site-packages (from pycaret-ts-alpha) (1.8.4)
# Requirement already satisfied: colorlover>=0.2.1 in /opt/conda/lib/python3.9/site-packages (from cufflinks>=0.17.0->pycaret-ts-alpha) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /opt/conda/lib/python3.9/site-packages (from cufflinks>=0.17.0->pycaret-ts-alpha) (1.16.0)
# Requirement already satisfied: setuptools>=34.4.1 in /opt/conda/lib/python3.9/site-packages (from cufflinks>=0.17.0->pycaret-ts-alpha) (60.5.0)
# Requirement already satisfied: smart-open>=1.8.1 in /opt/conda/lib/python3.9/site-packages (from gensim<4.0.0->pycaret-ts-alpha) (5.2.1)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.9/site-packages (from IPython->pycaret-ts-alpha) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.9/site-packages (from IPython->pycaret-ts-alpha) (0.18.1)
# Requirement already satisfied: traitlets>=4.2 in /opt/conda/lib/python3.9/site-packages (from IPython->pycaret-ts-alpha) (5.1.1)
# Requirement already satisfied: matplotlib-inline in /opt/conda/lib/python3.9/site-packages (from IPython->pycaret-ts-alpha) (0.1.3)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.9/site-packages (from IPython->pycaret-ts-alpha) (4.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/conda/lib/python3.9/site-packages (from IPython->pycaret-ts-alpha) (3.0.24)
# Requirement already satisfied: pygments in /opt/conda/lib/python3.9/site-packages (from IPython->pycaret-ts-alpha) (2.11.2)
# Requirement already satisfied: backcall in /opt/conda/lib/python3.9/site-packages (from IPython->pycaret-ts-alpha) (0.2.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.9/site-packages (from IPython->pycaret-ts-alpha) (5.1.1)
# Requirement already satisfied: nbformat>=4.2.0 in /opt/conda/lib/python3.9/site-packages (from ipywidgets->pycaret-ts-alpha) (5.1.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /opt/conda/lib/python3.9/site-packages (from ipywidgets->pycaret-ts-alpha) (3.5.2)
# Requirement already satisfied: ipykernel>=4.5.1 in /opt/conda/lib/python3.9/site-packages (from ipywidgets->pycaret-ts-alpha) (6.6.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /opt/conda/lib/python3.9/site-packages (from ipywidgets->pycaret-ts-alpha) (1.0.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /opt/conda/lib/python3.9/site-packages (from ipywidgets->pycaret-ts-alpha) (0.2.0)
# Requirement already satisfied: wheel in /opt/conda/lib/python3.9/site-packages (from lightgbm>=2.3.1->pycaret-ts-alpha) (0.37.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.9/site-packages (from matplotlib->pycaret-ts-alpha) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib->pycaret-ts-alpha) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib->pycaret-ts-alpha) (3.0.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib->pycaret-ts-alpha) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib->pycaret-ts-alpha) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.9/site-packages (from matplotlib->pycaret-ts-alpha) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib->pycaret-ts-alpha) (4.28.5)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.9/site-packages (from pandas->pycaret-ts-alpha) (2021.3)
# Requirement already satisfied: jinja2>=2.11.1 in /opt/conda/lib/python3.9/site-packages (from pandas-profiling>=2.8.0->pycaret-ts-alpha) (3.0.3)
# Requirement already satisfied: tqdm>=4.48.2 in /opt/conda/lib/python3.9/site-packages (from pandas-profiling>=2.8.0->pycaret-ts-alpha) (4.62.3)
# Requirement already satisfied: requests>=2.24.0 in /opt/conda/lib/python3.9/site-packages (from pandas-profiling>=2.8.0->pycaret-ts-alpha) (2.27.1)
# Requirement already satisfied: multimethod>=1.4 in /opt/conda/lib/python3.9/site-packages (from pandas-profiling>=2.8.0->pycaret-ts-alpha) (1.6)
# Requirement already satisfied: tangled-up-in-unicode==0.1.0 in /opt/conda/lib/python3.9/site-packages (from pandas-profiling>=2.8.0->pycaret-ts-alpha) (0.1.0)
# Requirement already satisfied: visions[type_image_path]==0.7.4 in /opt/conda/lib/python3.9/site-packages (from pandas-profiling>=2.8.0->pycaret-ts-alpha) (0.7.4)
# Requirement already satisfied: phik>=0.11.1 in /opt/conda/lib/python3.9/site-packages (from pandas-profiling>=2.8.0->pycaret-ts-alpha) (0.12.0)
# Requirement already satisfied: markupsafe~=2.0.1 in /opt/conda/lib/python3.9/site-packages (from pandas-profiling>=2.8.0->pycaret-ts-alpha) (2.0.1)
# Requirement already satisfied: missingno>=0.4.2 in /opt/conda/lib/python3.9/site-packages (from pandas-profiling>=2.8.0->pycaret-ts-alpha) (0.5.0)
# Requirement already satisfied: pydantic>=1.8.1 in /opt/conda/lib/python3.9/site-packages (from pandas-profiling>=2.8.0->pycaret-ts-alpha) (1.9.0)
# Requirement already satisfied: htmlmin>=0.1.12 in /opt/conda/lib/python3.9/site-packages (from pandas-profiling>=2.8.0->pycaret-ts-alpha) (0.1.12)
# Requirement already satisfied: attrs>=19.3.0 in /opt/conda/lib/python3.9/site-packages (from visions[type_image_path]==0.7.4->pandas-profiling>=2.8.0->pycaret-ts-alpha) (21.4.0)
# Requirement already satisfied: networkx>=2.4 in /opt/conda/lib/python3.9/site-packages (from visions[type_image_path]==0.7.4->pandas-profiling>=2.8.0->pycaret-ts-alpha) (2.6.3)
# Requirement already satisfied: imagehash in /opt/conda/lib/python3.9/site-packages (from visions[type_image_path]==0.7.4->pandas-profiling>=2.8.0->pycaret-ts-alpha) (4.2.1)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.9/site-packages (from plotly>=5.0.0->pycaret-ts-alpha) (8.0.1)
# Requirement already satisfied: urllib3 in /opt/conda/lib/python3.9/site-packages (from pmdarima>=1.8.0->pycaret-ts-alpha) (1.26.8)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in /opt/conda/lib/python3.9/site-packages (from pmdarima>=1.8.0->pycaret-ts-alpha) (0.29.26)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.9/site-packages (from scikit-learn~=0.24.2->pycaret-ts-alpha) (3.0.0)
# Requirement already satisfied: llvmlite<0.38,>=0.37.0rc1 in /opt/conda/lib/python3.9/site-packages (from numba->pycaret-ts-alpha) (0.37.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /opt/conda/lib/python3.9/site-packages (from spacy<2.4.0->pycaret-ts-alpha) (1.0.5)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /opt/conda/lib/python3.9/site-packages (from spacy<2.4.0->pycaret-ts-alpha) (1.0.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/lib/python3.9/site-packages (from spacy<2.4.0->pycaret-ts-alpha) (3.0.6)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /opt/conda/lib/python3.9/site-packages (from spacy<2.4.0->pycaret-ts-alpha) (1.1.3)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /opt/conda/lib/python3.9/site-packages (from spacy<2.4.0->pycaret-ts-alpha) (0.7.5)
# Requirement already satisfied: thinc<7.5.0,>=7.4.1 in /opt/conda/lib/python3.9/site-packages (from spacy<2.4.0->pycaret-ts-alpha) (7.4.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.9/site-packages (from spacy<2.4.0->pycaret-ts-alpha) (1.0.6)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.9/site-packages (from spacy<2.4.0->pycaret-ts-alpha) (2.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /opt/conda/lib/python3.9/site-packages (from spacy<2.4.0->pycaret-ts-alpha) (0.9.0)
# Requirement already satisfied: patsy>=0.5 in /opt/conda/lib/python3.9/site-packages (from statsmodels~=0.12.1->pycaret-ts-alpha) (0.5.2)
# Requirement already satisfied: entrypoints in /opt/conda/lib/python3.9/site-packages (from mlflow->pycaret-ts-alpha) (0.3)
# Requirement already satisfied: sqlalchemy in /opt/conda/lib/python3.9/site-packages (from mlflow->pycaret-ts-alpha) (1.4.29)
# Requirement already satisfied: Flask in /opt/conda/lib/python3.9/site-packages (from mlflow->pycaret-ts-alpha) (2.0.2)
# Requirement already satisfied: sqlparse>=0.3.1 in /opt/conda/lib/python3.9/site-packages (from mlflow->pycaret-ts-alpha) (0.4.2)
# Requirement already satisfied: alembic<=1.4.1 in /opt/conda/lib/python3.9/site-packages (from mlflow->pycaret-ts-alpha) (1.4.1)
# Requirement already satisfied: prometheus-flask-exporter in /opt/conda/lib/python3.9/site-packages (from mlflow->pycaret-ts-alpha) (0.18.7)
# Requirement already satisfied: querystring-parser in /opt/conda/lib/python3.9/site-packages (from mlflow->pycaret-ts-alpha) (1.2.4)
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.9/site-packages (from mlflow->pycaret-ts-alpha) (8.0.3)
# Requirement already satisfied: gunicorn in /opt/conda/lib/python3.9/site-packages (from mlflow->pycaret-ts-alpha) (20.1.0)
# Requirement already satisfied: databricks-cli>=0.8.7 in /opt/conda/lib/python3.9/site-packages (from mlflow->pycaret-ts-alpha) (0.16.2)
# Requirement already satisfied: protobuf>=3.7.0 in /opt/conda/lib/python3.9/site-packages (from mlflow->pycaret-ts-alpha) (3.19.2)
# Requirement already satisfied: docker>=4.0.0 in /opt/conda/lib/python3.9/site-packages (from mlflow->pycaret-ts-alpha) (5.0.3)
# Requirement already satisfied: importlib-metadata!=4.7.0,>=3.7.0 in /opt/conda/lib/python3.9/site-packages (from mlflow->pycaret-ts-alpha) (4.10.0)
# Requirement already satisfied: gitpython>=2.1.0 in /opt/conda/lib/python3.9/site-packages (from mlflow->pycaret-ts-alpha) (3.1.26)
# Requirement already satisfied: cloudpickle in /opt/conda/lib/python3.9/site-packages (from mlflow->pycaret-ts-alpha) (2.0.0)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.9/site-packages (from nltk->pycaret-ts-alpha) (2021.11.10)
# Requirement already satisfied: funcy in /opt/conda/lib/python3.9/site-packages (from pyLDAvis->pycaret-ts-alpha) (1.17)
# Requirement already satisfied: numexpr in /opt/conda/lib/python3.9/site-packages (from pyLDAvis->pycaret-ts-alpha) (2.8.0)
# Requirement already satisfied: future in /opt/conda/lib/python3.9/site-packages (from pyLDAvis->pycaret-ts-alpha) (0.18.2)
# Requirement already satisfied: pynndescent>=0.5 in /opt/conda/lib/python3.9/site-packages (from umap-learn->pycaret-ts-alpha) (0.5.5)
# Requirement already satisfied: python-editor>=0.3 in /opt/conda/lib/python3.9/site-packages (from alembic<=1.4.1->mlflow->pycaret-ts-alpha) (1.0.4)
# Requirement already satisfied: Mako in /opt/conda/lib/python3.9/site-packages (from alembic<=1.4.1->mlflow->pycaret-ts-alpha) (1.1.6)
# Requirement already satisfied: tabulate>=0.7.7 in /opt/conda/lib/python3.9/site-packages (from databricks-cli>=0.8.7->mlflow->pycaret-ts-alpha) (0.8.9)
# Requirement already satisfied: websocket-client>=0.32.0 in /opt/conda/lib/python3.9/site-packages (from docker>=4.0.0->mlflow->pycaret-ts-alpha) (1.2.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.9/site-packages (from gitpython>=2.1.0->mlflow->pycaret-ts-alpha) (4.0.9)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.9/site-packages (from importlib-metadata!=4.7.0,>=3.7.0->mlflow->pycaret-ts-alpha) (3.7.0)
# Requirement already satisfied: jupyter-client<8.0 in /opt/conda/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret-ts-alpha) (7.1.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /opt/conda/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret-ts-alpha) (1.5.1)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret-ts-alpha) (1.5.4)
# Requirement already satisfied: tornado<7.0,>=4.2 in /opt/conda/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret-ts-alpha) (6.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/conda/lib/python3.9/site-packages (from jedi>=0.16->IPython->pycaret-ts-alpha) (0.8.3)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /opt/conda/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets->pycaret-ts-alpha) (4.3.3)
# Requirement already satisfied: jupyter-core in /opt/conda/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets->pycaret-ts-alpha) (4.9.1)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.9/site-packages (from pexpect>4.3->IPython->pycaret-ts-alpha) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->pycaret-ts-alpha) (0.2.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.9/site-packages (from pydantic>=1.8.1->pandas-profiling>=2.8.0->pycaret-ts-alpha) (4.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests>=2.24.0->pandas-profiling>=2.8.0->pycaret-ts-alpha) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests>=2.24.0->pandas-profiling>=2.8.0->pycaret-ts-alpha) (3.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/lib/python3.9/site-packages (from requests>=2.24.0->pandas-profiling>=2.8.0->pycaret-ts-alpha) (2.0.10)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.9/site-packages (from sqlalchemy->mlflow->pycaret-ts-alpha) (1.1.2)
# Requirement already satisfied: notebook>=4.4.1 in /opt/conda/lib/python3.9/site-packages (from widgetsnbextension~=3.5.0->ipywidgets->pycaret-ts-alpha) (6.4.6)
# Requirement already satisfied: itsdangerous>=2.0 in /opt/conda/lib/python3.9/site-packages (from Flask->mlflow->pycaret-ts-alpha) (2.0.1)
# Requirement already satisfied: Werkzeug>=2.0 in /opt/conda/lib/python3.9/site-packages (from Flask->mlflow->pycaret-ts-alpha) (2.0.2)
# Requirement already satisfied: prometheus-client in /opt/conda/lib/python3.9/site-packages (from prometheus-flask-exporter->mlflow->pycaret-ts-alpha) (0.12.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->gitpython>=2.1.0->mlflow->pycaret-ts-alpha) (5.0.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/conda/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->pycaret-ts-alpha) (0.18.0)
# Requirement already satisfied: pyzmq>=13 in /opt/conda/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets->pycaret-ts-alpha) (22.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /opt/conda/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret-ts-alpha) (1.8.0)
# Requirement already satisfied: nbconvert in /opt/conda/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret-ts-alpha) (6.4.0)
# Requirement already satisfied: argon2-cffi in /opt/conda/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret-ts-alpha) (21.3.0)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret-ts-alpha) (0.12.1)
# Requirement already satisfied: PyWavelets in /opt/conda/lib/python3.9/site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling>=2.8.0->pycaret-ts-alpha) (1.2.0)
# Requirement already satisfied: argon2-cffi-bindings in /opt/conda/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret-ts-alpha) (21.2.0)
# Requirement already satisfied: testpath in /opt/conda/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret-ts-alpha) (0.5.0)
# Requirement already satisfied: jupyterlab-pygments in /opt/conda/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret-ts-alpha) (0.1.2)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret-ts-alpha) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/conda/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret-ts-alpha) (0.8.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /opt/conda/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret-ts-alpha) (0.5.9)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret-ts-alpha) (1.5.0)
# Requirement already satisfied: bleach in /opt/conda/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret-ts-alpha) (4.1.0)
# Requirement already satisfied: cffi>=1.0.1 in /opt/conda/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret-ts-alpha) (1.15.0)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret-ts-alpha) (0.5.1)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret-ts-alpha) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
train = pd.read_csv('train.zip', index_col='id')
display(train.sample(2))
# Out:
# Period
# 1949-01    112.0
# 1949-02    118.0
# 1949-03    132.0
# 1949-04    129.0
# 1949-05    121.0
# Freq: M, Name: Number of airline passengers, dtype: float64

# %%
fh = 12 # or alternately fh = np.arange(1,13)
fold = 3

# %%
exp = TimeSeriesExperiment()
exp.setup(data=y, fh=fh)
exp.models()
# Out:
# <style type="text/css">
# #T_bb28a_row9_col1, #T_bb28a_row11_col1, #T_bb28a_row13_col1, #T_bb28a_row14_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_bb28a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bb28a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bb28a_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_bb28a_row0_col1" class="data row0 col1" >1770</td>
#     </tr>
#     <tr>
#       <th id="T_bb28a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bb28a_row1_col0" class="data row1 col0" >Original Data</td>
#       <td id="T_bb28a_row1_col1" class="data row1 col1" >(144, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_bb28a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bb28a_row2_col0" class="data row2 col0" >Missing Values</td>
#       <td id="T_bb28a_row2_col1" class="data row2 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_bb28a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bb28a_row3_col0" class="data row3 col0" >Transformed Train Set</td>
#       <td id="T_bb28a_row3_col1" class="data row3 col1" >(132,)</td>
#     </tr>
#     <tr>
#       <th id="T_bb28a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bb28a_row4_col0" class="data row4 col0" >Transformed Test Set</td>
#       <td id="T_bb28a_row4_col1" class="data row4 col1" >(12,)</td>
#     </tr>
#     <tr>
#       <th id="T_bb28a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_bb28a_row5_col0" class="data row5 col0" >Fold Generator</td>
#       <td id="T_bb28a_row5_col1" class="data row5 col1" >ExpandingWindowSplitter</td>
#     </tr>
#     <tr>
#       <th id="T_bb28a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_bb28a_row6_col0" class="data row6 col0" >Fold Number</td>
#       <td id="T_bb28a_row6_col1" class="data row6 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_bb28a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_bb28a_row7_col0" class="data row7 col0" >Enforce Prediction Interval</td>
#       <td id="T_bb28a_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_bb28a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_bb28a_row8_col0" class="data row8 col0" >Seasonal Period Tested</td>
#       <td id="T_bb28a_row8_col1" class="data row8 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_bb28a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_bb28a_row9_col0" class="data row9 col0" >Seasonality Detected</td>
#       <td id="T_bb28a_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_bb28a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_bb28a_row10_col0" class="data row10 col0" >Seasonality Used in Models</td>
#       <td id="T_bb28a_row10_col1" class="data row10 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_bb28a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_bb28a_row11_col0" class="data row11 col0" >Target Strictly Positive</td>
#       <td id="T_bb28a_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_bb28a_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_bb28a_row12_col0" class="data row12 col0" >Target White Noise</td>
#       <td id="T_bb28a_row12_col1" class="data row12 col1" >No</td>
#     </tr>
#     <tr>
#       <th id="T_bb28a_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_bb28a_row13_col0" class="data row13 col0" >Recommended d</td>
#       <td id="T_bb28a_row13_col1" class="data row13 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_bb28a_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_bb28a_row14_col0" class="data row14 col0" >Recommended Seasonal D</td>
#       <td id="T_bb28a_row14_col1" class="data row14 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_bb28a_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_bb28a_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_bb28a_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_bb28a_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_bb28a_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_bb28a_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_bb28a_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_bb28a_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_bb28a_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_bb28a_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_bb28a_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_bb28a_row18_col1" class="data row18 col1" >ts-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_bb28a_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_bb28a_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_bb28a_row19_col1" class="data row19 col1" >6e14</td>
#     </tr>
#     <tr>
#       <th id="T_bb28a_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_bb28a_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_bb28a_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#   </tbody>
# </table>
#                                                               Name  \
# ID
# naive                                             Naive Forecaster
# grand_means                                 Grand Means Forecaster
# snaive                                   Seasonal Naive Forecaster
# polytrend                              Polynomial Trend Forecaster
# arima                                                        ARIMA
# auto_arima                                              Auto ARIMA
# exp_smooth                                   Exponential Smoothing
# ets                                                            ETS
# theta                                             Theta Forecaster
# tbats                                                        TBATS
# bats                                                          BATS
# lr_cds_dt               Linear w/ Cond. Deseasonalize & Detrending
# en_cds_dt          Elastic Net w/ Cond. Deseasonalize & Detrending
# ridge_cds_dt             Ridge w/ Cond. Deseasonalize & Detrending
# lasso_cds_dt             Lasso w/ Cond. Deseasonalize & Detrending
# lar_cds_dt       Least Angular Regressor w/ Cond. Deseasonalize...
# llar_cds_dt      Lasso Least Angular Regressor w/ Cond. Deseaso...
# br_cds_dt        Bayesian Ridge w/ Cond. Deseasonalize & Detren...
# huber_cds_dt             Huber w/ Cond. Deseasonalize & Detrending
# par_cds_dt       Passive Aggressive w/ Cond. Deseasonalize & De...
# omp_cds_dt       Orthogonal Matching Pursuit w/ Cond. Deseasona...
# knn_cds_dt         K Neighbors w/ Cond. Deseasonalize & Detrending
# dt_cds_dt        Decision Tree w/ Cond. Deseasonalize & Detrending
# rf_cds_dt        Random Forest w/ Cond. Deseasonalize & Detrending
# et_cds_dt          Extra Trees w/ Cond. Deseasonalize & Detrending
# gbr_cds_dt       Gradient Boosting w/ Cond. Deseasonalize & Det...
# ada_cds_dt            AdaBoost w/ Cond. Deseasonalize & Detrending
# lightgbm_cds_dt  Light Gradient Boosting w/ Cond. Deseasonalize...
#
#                                                          Reference  Turbo
# ID
# naive                     sktime.forecasting.naive.NaiveForecaster   True
# grand_means               sktime.forecasting.naive.NaiveForecaster   True
# snaive                    sktime.forecasting.naive.NaiveForecaster   True
# polytrend        sktime.forecasting.trend.PolynomialTrendForeca...   True
# arima                               sktime.forecasting.arima.ARIMA   True
# auto_arima                      sktime.forecasting.arima.AutoARIMA   True
# exp_smooth       sktime.forecasting.exp_smoothing.ExponentialSm...   True
# ets                                 sktime.forecasting.ets.AutoETS   True
# theta                     sktime.forecasting.theta.ThetaForecaster   True
# tbats                               sktime.forecasting.tbats.TBATS  False
# bats                                  sktime.forecasting.bats.BATS  False
# lr_cds_dt        pycaret.containers.models.time_series.BaseCdsD...   True
# en_cds_dt        pycaret.containers.models.time_series.BaseCdsD...   True
# ridge_cds_dt     pycaret.containers.models.time_series.BaseCdsD...   True
# lasso_cds_dt     pycaret.containers.models.time_series.BaseCdsD...   True
# lar_cds_dt       pycaret.containers.models.time_series.BaseCdsD...   True
# llar_cds_dt      pycaret.containers.models.time_series.BaseCdsD...   True
# br_cds_dt        pycaret.containers.models.time_series.BaseCdsD...   True
# huber_cds_dt     pycaret.containers.models.time_series.BaseCdsD...   True
# par_cds_dt       pycaret.containers.models.time_series.BaseCdsD...   True
# omp_cds_dt       pycaret.containers.models.time_series.BaseCdsD...   True
# knn_cds_dt       pycaret.containers.models.time_series.BaseCdsD...   True
# dt_cds_dt        pycaret.containers.models.time_series.BaseCdsD...   True
# rf_cds_dt        pycaret.containers.models.time_series.BaseCdsD...   True
# et_cds_dt        pycaret.containers.models.time_series.BaseCdsD...   True
# gbr_cds_dt       pycaret.containers.models.time_series.BaseCdsD...   True
# ada_cds_dt       pycaret.containers.models.time_series.BaseCdsD...   True
# lightgbm_cds_dt  pycaret.containers.models.time_series.BaseCdsD...   True
